# %%
## Importing Lib's
from tensorflow.keras.preprocessing.text import one_hot

# %%
## Sentence
sent=['the glass of milk',
     'the glass of juice',
     'the cup of tea',
     'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Defining Vocabulary Size 
voc_size = 10000

# %%
## One Hot Representation
one_hot_rep = [one_hot(words,voc_size) for words in sent]
one_hot_rep
# Out:
# [[3721, 3672, 6450, 6884],
#  [3721, 3672, 6450, 3],
#  [3721, 8380, 6450, 7698],
#  [8884, 8520, 2222, 1180, 8557],
#  [8884, 8520, 2222, 1180, 8501],
#  [5660, 3721, 3557, 6450, 5414],
#  [8218, 3592, 8343, 1180]]

# %%
##  Word Embedding Representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential
import numpy as np
import pandas as pd

# %%
sent_length = 8
embedded_docs = pad_sequences(one_hot_rep, padding='pre', maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 3721 3672 6450 6884]
#  [   0    0    0    0 3721 3672 6450    3]
#  [   0    0    0    0 3721 8380 6450 7698]
#  [   0    0    0 8884 8520 2222 1180 8557]
#  [   0    0    0 8884 8520 2222 1180 8501]
#  [   0    0    0 5660 3721 3557 6450 5414]
#  [   0    0    0    0 8218 3592 8343 1180]]

# %%
## Feature Representation
dim = 10
model = Sequential()
model.add(Embedding(input_dim=voc_size, output_dim=dim, input_length=sent_length))
model.compile('adam','mse')
model.summary()
# Out:
# d:\Projects\Simple RNN Movies Review (IMDB)\venv\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# array([[[-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.04398065,  0.0478673 ,  0.00368836,  0.00070176,
#           0.0359501 ,  0.01186603, -0.03380515,  0.02037213,
#           0.01204078,  0.03569199],
#         [-0.02605753, -0.04559983,  0.00937468, -0.02384019,
#          -0.00566634,  0.01682521, -0.01680381,  0.01971311,
#          -0.0190238 , -0.0266149 ],
#         [-0.03782951, -0.02559153,  0.0247103 , -0.02186369,
#           0.0191232 , -0.01136764,  0.04927744,  0.0019833 ,
#          -0.00335569,  0.04845778],
#         [-0.02562454,  0.03477186,  0.02800561, -0.01949705,
#          -0.00118482, -0.00838991,  0.01076023,  0.02305868,
#          -0.0268921 ,  0.01671558]],
#
#        [[-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.04398065,  0.0478673 ,  0.00368836,  0.00070176,
#           0.0359501 ,  0.01186603, -0.03380515,  0.02037213,
#           0.01204078,  0.03569199],
#         [-0.02605753, -0.04559983,  0.00937468, -0.02384019,
#          -0.00566634,  0.01682521, -0.01680381,  0.01971311,
#          -0.0190238 , -0.0266149 ],
#         [-0.03782951, -0.02559153,  0.0247103 , -0.02186369,
#           0.0191232 , -0.01136764,  0.04927744,  0.0019833 ,
#          -0.00335569,  0.04845778],
#         [ 0.00479083, -0.0453898 ,  0.02560702, -0.00140116,
#          -0.04460597,  0.00257553,  0.01177499, -0.01683539,
#           0.02292141,  0.01652594]],
#
#        [[-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.04398065,  0.0478673 ,  0.00368836,  0.00070176,
#           0.0359501 ,  0.01186603, -0.03380515,  0.02037213,
#           0.01204078,  0.03569199],
#         [-0.03540192,  0.02081213,  0.01673635,  0.04087727,
#          -0.04526407,  0.04124681, -0.0274618 ,  0.03132807,
#           0.0147847 , -0.04241803],
#         [-0.03782951, -0.02559153,  0.0247103 , -0.02186369,
#           0.0191232 , -0.01136764,  0.04927744,  0.0019833 ,
#          -0.00335569,  0.04845778],
#         [ 0.02979585,  0.0230831 , -0.01927581, -0.00219624,
#           0.02850148, -0.02852745, -0.02085247,  0.04547459,
#           0.00847856, -0.01161281]],
#
#        [[-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00311252, -0.02641103,  0.02755895, -0.01071575,
#           0.0120911 ,  0.03934706,  0.02832819, -0.02733725,
#          -0.03508037, -0.04504482],
#         [-0.03146384,  0.01118112, -0.00719901,  0.02103409,
#           0.04472848, -0.01834869,  0.02076784, -0.03987591,
#           0.0416881 , -0.01968776],
#         [ 0.04520922, -0.0256099 ,  0.025476  ,  0.04995902,
#           0.02812647, -0.03793079, -0.0207664 ,  0.00357021,
#          -0.01747469, -0.02255976],
#         [-0.01713281, -0.01326926, -0.01122117,  0.0007888 ,
#          -0.01683706,  0.02775395,  0.04976751, -0.00082033,
#          -0.01217781, -0.02447571],
#         [ 0.04831943,  0.0134916 ,  0.04572662,  0.04653448,
#           0.01361456,  0.03673341,  0.00276168, -0.03579526,
#          -0.04963881,  0.02946549]],
#
#        [[-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00311252, -0.02641103,  0.02755895, -0.01071575,
#           0.0120911 ,  0.03934706,  0.02832819, -0.02733725,
#          -0.03508037, -0.04504482],
#         [-0.03146384,  0.01118112, -0.00719901,  0.02103409,
#           0.04472848, -0.01834869,  0.02076784, -0.03987591,
#           0.0416881 , -0.01968776],
#         [ 0.04520922, -0.0256099 ,  0.025476  ,  0.04995902,
#           0.02812647, -0.03793079, -0.0207664 ,  0.00357021,
#          -0.01747469, -0.02255976],
#         [-0.01713281, -0.01326926, -0.01122117,  0.0007888 ,
#          -0.01683706,  0.02775395,  0.04976751, -0.00082033,
#          -0.01217781, -0.02447571],
#         [ 0.02499932, -0.02926065, -0.04200288,  0.02414894,
#           0.0171121 ,  0.01490368, -0.01093746, -0.01574112,
#           0.01364828,  0.00888469]],
#
#        [[-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [ 0.02282805, -0.00462968,  0.03948733, -0.0412894 ,
#           0.04676987, -0.02257596,  0.0273085 ,  0.04771341,
#           0.00640891,  0.03275141],
#         [-0.04398065,  0.0478673 ,  0.00368836,  0.00070176,
#           0.0359501 ,  0.01186603, -0.03380515,  0.02037213,
#           0.01204078,  0.03569199],
#         [-0.02385972,  0.04791805,  0.04723947, -0.03105227,
#           0.02295775,  0.01883073,  0.02811724, -0.02908659,
#          -0.04035982,  0.03485465],
#         [-0.03782951, -0.02559153,  0.0247103 , -0.02186369,
#           0.0191232 , -0.01136764,  0.04927744,  0.0019833 ,
#          -0.00335569,  0.04845778],
#         [ 0.030883  ,  0.01361206,  0.00326686,  0.02232498,
#           0.00455891,  0.04358209, -0.00459711,  0.01246845,
#          -0.02976662,  0.00340747]],
#
#        [[-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.00073578,  0.04388392, -0.01813886, -0.01466339,
#          -0.03756964,  0.04954093, -0.01508986,  0.0102759 ,
#           0.04597289, -0.0285732 ],
#         [-0.03574549, -0.00337651, -0.03973181,  0.02613889,
#          -0.03651097,  0.03791079,  0.01995308,  0.04528068,
#          -0.00392194,  0.04365016],
#         [-0.02181429,  0.02721849,  0.00971981,  0.03483437,
#           0.03518993, -0.03708748,  0.04134062, -0.02550834,
#           0.02685524, -0.04961374],
#         [-0.0245512 ,  0.00924399,  0.04605151,  0.04578625,
#          -0.00578879, -0.00139908, -0.01239023, -0.02321216,
#          -0.04742892,  0.0190431 ],
#         [-0.01713281, -0.01326926, -0.01122117,  0.0007888 ,
#          -0.01683706,  0.02775395,  0.04976751, -0.00082033,
#          -0.01217781, -0.02447571]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 3721, 3672, 6450, 6884], dtype=int32)
